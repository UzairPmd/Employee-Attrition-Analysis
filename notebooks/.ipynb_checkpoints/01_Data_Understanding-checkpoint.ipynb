# %% [markdown]
# ## Employee Attrition Analysis

# %%
# =====================================================
# Employee Attrition Analysis
# Step 1 : Data Understanding
# Author : Uzair
# =====================================================

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## 2.Load the Dataset

# %%
df = pd.read_csv("../data/raw/WA_Fn-UseC_-HR-Employee-Attrition.csv")
df.sample(5, random_state=42)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 1041   28        No  Travel_Rarely        866                   Sales
# 184    53        No  Travel_Rarely       1084  Research & Development
# 1222   24       Yes  Travel_Rarely        240         Human Resources
# 67     45        No  Travel_Rarely       1339  Research & Development
# 220    36        No  Travel_Rarely       1396  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 1041                 5          3          Medical              1
# 184                 13          2          Medical              1
# 1222                22          1  Human Resources              1
# 67                   7          3    Life Sciences              1
# 220                  5          2    Life Sciences              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 1041            1469                        4    Male          84
# ...

# %% [markdown]
# ## 3.Data Overview

# %%
print(f"Number of Rows    : {df.shape[0]}")
print(f"Number of Columns : {df.shape[1]}")
# Out:
# Number of Rows    : 1470
# Number of Columns : 35

# %% [markdown]
# ### Observation
#
# - The dataset contains **1470 employee records**.
# - There are **35 features** describing employee demographics, job characteristics, performance, compensation, and attrition status.

# %% [markdown]
# ## 4.Data Types

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   str
#  2   BusinessTravel            1470 non-null   str
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   str
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   str
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   str
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# ### Observation
# - All columns have **1470 non-null values**, indicating no obvious missing values.
# - There are **26 numerical** and **9 categorical** features.
# - The data types appear appropriate for the available variables.
# - A few columns such as `EmployeeCount`, `EmployeeNumber`, `Over18`, and `StandardHours` may require further investigation during the data cleaning phase to determine whether they contribute meaningful information.

# %% [markdown]
# ## 5.Missing Values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# ### Observation
# - So far there are no null values in any columns.

# %% [markdown]
# ## 6.Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Observation
# - No duplicates values were found in the dataset.

# %% [markdown]
# ## Conclusion
# The initial assessment of the employee attrition dataset indicates that it is well-structured and ready for analysis.
#
# Key findings from the data understanding phase:
#
# - The dataset contains **1,470 employee records** and **35 features**.
# - No missing values were detected.
# - No duplicate records were found.
# - The data types are appropriate for analysis.
# - Some columns such as `EmployeeCount`, `Over18`, `StandardHours`, and `EmployeeNumber` require further evaluation during the data cleaning phase to determine their analytical relevance.
